# %% [markdown]
# # Medical chatbot

# %% [markdown]
# # Backend Architecture

# %% [markdown]
# ![Backend Architecture](image.png)

# %% [markdown]
# # Front end Architecture

# %% [markdown]
# ![front end Architecture](image2.png)

# %% [markdown]
# # Tech stack
# 1. Programming lang -> Python
# 2. Lnagchain/Llama Index ->Gen Ai Framework
# 3. Front End -> Flask
# 4. LLM -> Meta llama2
# 5. VectorDb  -> Pinecone
